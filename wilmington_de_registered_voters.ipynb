# %% [markdown]
# Import numpy and pandas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Using the bash magic command, view the list of files inside of the data directory.

# %%
# 
# %ls
# Out:
# ActiveFile-Wilm1thru8-20191015.csv
# DE-VoterFile-Documentation 20171010.pdf

# %%
# %cd data
# Out:
# [Errno 2] No such file or directory: 'data'
# /Users/sheng/Jupyter/DataEngineering.Labs.RegisteredVotersFileWilmingtonDE/data

# %%
# %ls
# Out:
# ActiveFile-Wilm1thru8-20191015.csv
# DE-VoterFile-Documentation 20171010.pdf

# %% [markdown]
# Load the csv file into a Pandas DataFrame.

# %%
# 
df = pd.read_csv('/Users/sheng/Jupyter/DataEngineering.Labs.RegisteredVotersFileWilmingtonDE/data/ActiveFile-Wilm1thru8-20191015.csv')
# Out:
# /Users/sheng/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (18,32,35,36,37,40,41,42,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Display a list of columns in the DataFrame.

# %%
df.columns
# Out:
# Index(['UNIQUE-ID', 'LAST-NAME', 'FIRST-NAME', 'MID-INIT', 'SUFFIX',
#        'YEAR-OF-BIRTH', 'HOME-NO', 'HOME-APT', 'HOME-STREET', 'HOME-DEV',
#        'HOME-CITY', 'HOME-ZIPCODE', 'COUNTY', 'ED', 'RD', 'SD', 'CNLEVY',
#        'WILM', 'CODE-HOME-CITY', 'SCH-DIST', 'PARTY', 'DATE-REG', 'PP-HIST-1',
#        'PP-HIST-2', 'PR-HIST-1', 'PR-HIST-2', 'PR-HIST-3', 'GEN-HIST-1',
#        'GEN-HIST-2', 'GEN-HIST-3', 'GEN-HIST-4', 'GEN-HIST-5', 'SP-HIST-1',
#        'SP-HIST-2', 'SP-HIST-3', 'SCHL-HIST-1', 'SCHL-HIST-2', 'SCHL-HIST-3',
#        'SCHL-HIST-4', 'SCHL-HIST-5', 'REF-HIST-1', 'REF-HIST-2', 'REF-HIST-3',
#        'REF-HIST-4', 'REF-HIST-5', 'MAIL-NO', 'MAIL-APT', 'MAIL-STR',
#        'MAIL-CITY', 'MAIL-STATE', 'MAIL-ZIP', 'DATE-LAST-CHG', 'CODE-CHANGE',
#        'STATUS'],
#       dtype='object')

# %% [markdown]
# What is the shape of this DataFrame? How many columns does each row have? How many rows are there?

# %%
df.describe()
# Out:
#           UNIQUE-ID  YEAR-OF-BIRTH  HOME-ZIPCODE            ED            RD  \
# count  5.190900e+04   51909.000000  51909.000000  51909.000000  51909.000000
# mean   1.007288e+08    1973.077270  19803.345297      5.842860      2.934828
# std    3.282878e+05      18.043989      1.928276      3.416253      2.783597
# min    1.000000e+08    1900.000000  19801.000000      1.000000      1.000000
# 25%    1.004716e+08    1959.000000  19802.000000      3.000000      1.000000
# 50%    1.007901e+08    1976.000000  19802.000000      6.000000      2.000000
# 75%    1.010212e+08    1988.000000  19805.000000      9.000000      3.000000
# max    1.012025e+08    2002.000000  19807.000000     16.000000     16.000000
#
#                  SD        CNLEVY          WILM      DATE-REG     PP-HIST-1  \
# count  51909.000000  51909.000000  51909.000000  5.190900e+04  51909.000000
# mean       2.236298      6.380859      4.541159  2.004053e+07    416.528617
# ...

# %%
df.shape
# Out:
# (51909, 54)

# %%
df['HOME-ZIPCODE'].unique()
# Out:
# array([19801, 19806, 19802, 19805, 19807])

# %%
df.tail()
# Out:
#        UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 51904  100876849   BROOMER  CHERLOTTE        D    NaN           1974    1340
# 51905  100251665     HANEY     JANICE        M    NaN           1952      21
# 51906  101029340    MARTIN    ELMARIA        D    NaN           1966    2910
# 51907  101145618      ROSE    KENISHA        A    NaN           1989    1300
# 51908  100807909     ALLEN      SARAH        E    NaN           1987    1618
#
#       HOME-APT    HOME-STREET      HOME-DEV  ... REF-HIST-5  MAIL-NO MAIL-APT  \
# 51904      NaN  LANCASTER AVE           NaN  ...        NaN      NaN      NaN
# 51905      NaN         IVY RD           NaN  ...        NaN      NaN      NaN
# 51906      NaN      N WEST ST           NaN  ...        NaN      NaN      NaN
# 51907    #A401  N HARRISON ST  MAYFAIR APTS  ...        NaN      NaN      NaN
# 51908    FL #2     N BROOM ST           NaN  ...        NaN      NaN      NaN
#
# ...

# %% [markdown]
# # HOME ZIP CODE

# %% [markdown]
# Group objects using the HOME-ZIPCODE column. Assign the value to a variable called grouped_zc.
# [Pandas Groupby User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)

# %%
grouped_zc = df.groupby('HOME-ZIPCODE')
grouped_zc.first()
# Out:
#               UNIQUE-ID     LAST-NAME FIRST-NAME MID-INIT SUFFIX  \
# HOME-ZIPCODE
# 19801         100234840           ROY    BEVERLY        A    3RD
# 19802         100349191       LAMBORN     GERALD        V     JR
# 19805         100394887  KRYSTOPOLSKI     ANDREW        R     JR
# 19806         100485262        HARRIS     JOSEPH        A    III
# 19807         100251586        KLOCKO     ANDREA        L     JR
#
#               YEAR-OF-BIRTH HOME-NO HOME-APT   HOME-STREET  \
# HOME-ZIPCODE
# 19801                  1952     320     #912      E 5TH ST
# 19802                  1958     706     #4-C     W 34TH ST
# 19805                  1981    1009      #1A  ANCHORAGE ST
# 19806                  1963    2616     #210     W 18TH ST
# 19807                  1966     509      NaN   REDFERN AVE
#
#                         HOME-DEV  ... REF-HIST-5      MAIL-NO  MAIL-APT  \
# HOME-ZIPCODE                      ...
# 19801         HERLIHY HOUSE APTS  ...        NaN   PO BOX 311      #378
# ...

# %%
grouped_zc.groups
# Out:
# {19801: [0, 1, 10, 12, 13, 15, 16, 20, 24, 34, 55, 56, 57, 58, 62, 64, 65, 67, 79, 92, 94, 95, 98, 102, 103, 110, 118, 120, 121, 129, 131, 136, 146, 149, 151, 157, 158, 173, 174, 180, 184, 188, 194, 197, 198, 202, 203, 210, 211, 215, 222, 223, 228, 229, 233, 241, 242, 263, 278, 281, 282, 284, 285, 286, 287, 288, 291, 292, 293, 294, 300, 301, 302, 310, 311, 312, 316, 317, 321, 322, 323, 324, 327, 333, 334, 336, 337, 339, 340, 343, 344, 345, 346, 347, 348, 349, 354, 357, 365, 372, ...], 19802: [3, 5, 11, 21, 29, 30, 31, 38, 39, 40, 45, 46, 51, 52, 53, 54, 59, 60, 61, 68, 69, 70, 76, 77, 78, 80, 84, 85, 88, 89, 91, 97, 99, 100, 101, 108, 109, 116, 122, 123, 124, 125, 130, 134, 135, 138, 139, 140, 143, 144, 145, 148, 154, 155, 156, 160, 162, 163, 172, 181, 186, 187, 195, 196, 200, 201, 205, 206, 207, 208, 213, 214, 220, 225, 226, 239, 240, 243, 245, 246, 250, 251, 252, 265, 270, 273, 275, 276, 277, 290, 299, 307, 308, 309, 313, 314, 315, 318, 319, 320, ...], 19805: [4, 6, 7, 8, 14, 17, 1
# ...

# %% [markdown]
# What type of object is grouped_zc?

# %%
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# DataFrameGroupBy objects contain a groups attribute. Display the value of the groups attribute belonging to the grouped_zc object.

# %%
grouped_zc.last()
# Out:
#               UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH  \
# HOME-ZIPCODE
# 19801         101158791   GOODMAN       JOHN        T    III           1993
# 19802         101029340    MARTIN    ELMARIA        D     JR           1966
# 19805         100876849   BROOMER  CHERLOTTE        D     JR           1974
# 19806         100807909     ALLEN      SARAH        E     JR           1987
# 19807         101195005      ODEH   JENNIFER        B     JR           1981
#
#              HOME-NO HOME-APT    HOME-STREET          HOME-DEV  ...  \
# HOME-ZIPCODE                                                    ...
# 19801            500     #112    HARLAN BLVD  JUSTISON LANDING  ...
# 19802           2910      #G1      N WEST ST  PEBBLE HILL APTS  ...
# 19805           1340      #F7  LANCASTER AVE        CANBY PARK  ...
# 19806           1618    FL #2     N BROOM ST      MAYFAIR APTS  ...
# 19807           1918      NaN  RISING SUN LN       WESTMORLAND  ...
#
# ...

# %% [markdown]
# Invoke the size method on the grouped_zc object to find out how many items are associated with each zip code.

# %%
grouped_zc.size()
# Out:
# HOME-ZIPCODE
# 19801    10730
# 19802    17182
# 19805    15548
# 19806     8326
# 19807      123
# dtype: int64

# %% [markdown]
# Use a magic command so that matplotlib graphics will display inline.

# %%
# %matplotlib inline

# %%
pie = grouped_zc['UNIQUE-ID'].count()

# %% [markdown]
# Create a pie chart illustrating the number of voters per zip code.

# %%
pie.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='UNIQUE-ID'>

# %% [markdown]
# # YEAR OF BIRTH

# %% [markdown]
# Group objects by the YEAR-OF-BIRTH column. Assign the value to an object called "grouped_yob".

# %%
grouped_yob = df.groupby('YEAR-OF-BIRTH')

# %% [markdown]
# Display the value of the groups attribute belonging the grouped_yob object.

# %%
grouped_yob.describe()
# Out:
#               UNIQUE-ID                                            \
#                   count          mean            std          min
# YEAR-OF-BIRTH
# 1900                1.0  1.010927e+08            NaN  101092654.0
# 1912                1.0  1.007809e+08            NaN  100780861.0
# 1915                2.0  1.006020e+08  146872.442413  100498097.0
# 1916                3.0  1.002868e+08  159551.212189  100133711.0
# 1917                2.0  1.004343e+08  374300.610660  100169674.0
# ...                 ...           ...            ...          ...
# 1998              786.0  1.010653e+08   52023.168610  101007853.0
# 1999              719.0  1.011158e+08   26077.536960  101092332.0
# 2000              717.0  1.011316e+08   32034.085328  101092217.0
# 2001              575.0  1.011736e+08    8257.273801  101162093.0
# 2002              395.0  1.011780e+08    8690.152250  101162091.0
#
#                                                                      \
# ...

# %%
grouped_yob.groups.keys()
# Out:
# dict_keys([1900, 1912, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002])

# %% [markdown]
# Select the object for the row indicating that the voter was born in 1900.

# %%
df[df['YEAR-OF-BIRTH'] == 1900]
# Out:
#        UNIQUE-ID LAST-NAME FIRST-NAME MID-INIT SUFFIX  YEAR-OF-BIRTH HOME-NO  \
# 49249  101092654   KENNEDY     JORDAN        D    NaN           1900     724
#
#       HOME-APT     HOME-STREET HOME-DEV  ... REF-HIST-5  MAIL-NO MAIL-APT  \
# 49249      NaN  N BANCROFT PKY      NaN  ...        NaN      NaN      NaN
#
#        MAIL-STR  MAIL-CITY  MAIL-STATE  MAIL-ZIP  DATE-LAST-CHG CODE-CHANGE  \
# 49249       NaN        NaN         NaN       NaN       20170731          P6
#
#       STATUS
# 49249      I
#
# [1 rows x 54 columns]

# %%
yob = df['YEAR-OF-BIRTH'].value_counts()
yob
# Out:
# 1990    1344
# 1991    1275
# 1989    1271
# 1988    1212
# 1992    1174
#         ...
# 1916       3
# 1915       2
# 1917       2
# 1900       1
# 1912       1
# Name: YEAR-OF-BIRTH, Length: 90, dtype: int64

# %% [markdown]
# Graph a histogram to  illustrate the age distribution of voters in this dataset. Ty using different values for the bins attribute of the histogram.

# %%
grouped_yob.size().plot.hist(bins=20)
#yob.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # PARTY

# %% [markdown]
# Group objects using the PARTY column. Assign the value to a variable called grouped_p.

# %%
grouped_p = df.groupby('PARTY')

# %% [markdown]
# Display the value of the groups attribute belonging to the grouped_p object.

# %%
grouped_p.groups.keys()
# Out:
# dict_keys(['A', 'B', 'D', 'E', 'G', 'H', 'I', 'J', 'L', 'M', 'O', 'Q', 'R', 'T', 'V', 'W', 'Y', 'Z'])

# %% [markdown]
# Invoke the size method on the grouped_p object to find out how many items are associated with each party.

# %%
grouped_p.size()
# Out:
# PARTY
# A       52
# B      441
# D    38020
# E       30
# G       42
# H       82
# I     7670
# J      161
# L       98
# M        1
# O       33
# Q       17
# R     4851
# T       14
# V       11
# W      333
# Y       14
# Z       39
# dtype: int64

# %%
grouped_p.nunique()
# Out:
#        UNIQUE-ID  LAST-NAME  FIRST-NAME  MID-INIT  SUFFIX  YEAR-OF-BIRTH  \
# PARTY
# A             52         49          49        13       2             29
# B            441        327         341        26       5             55
# D          38020       9841        9828        26      12             89
# E             30         29          29        13       1             21
# G             42         42          42        13       1             32
# H             82         78          79        21       2             43
# I           7670       4197        2642        27      10             86
# J            161        132         142        22       3             51
# L             98         96          82        16       5             40
# M              1          1           1         1       0              1
# O             33         33          33        13       1             27
# Q             17         16          17        10       2             16
# ...

# %% [markdown]
# Create a bar chart to visualize the number of voters associated with each party.

# %%
grouped_p.size().plot.bar()
# Out:
# <AxesSubplot:xlabel='PARTY'>

# %% [markdown]
# # Merging Two DataFrames

# %% [markdown]
# Using the data from the documentation, create a Pandas DataFrame that contains the party code and the corresponding legal name for each party.

# %%
# legal_names = {}

# %%
# df_legal_names = pd.DataFrame(legal_names)

# %%
# df_legal_names

# %% [markdown]
# Create a Pandas DataFrame that contains the Party code and the corresponding number of registered voters for said party.

# %%
# Create DataFrame df_party_counts here

# %%
# df_party_counts

# %% [markdown]
# Merge the two DataFrames.

# %%
# Merge DataFrame here

# %%
# Display new DataFrame here

# %% [markdown]
# Create a bar graph again but using the legal name for each party as the value on the x axes.

# %%
#
